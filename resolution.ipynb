# %%
import sympy as sp
sp.init_printing()

# %%
from my_resolution import d0, d1, d2, d3, d4, d5
from validate_resolution import composition

# %% [markdown]
# `composition(d0, d1)` takes two matrices $d_0$ and $d_1$ and computes the composition in the following sense:
#
# $$ \lambda x \to d_0 (d_1 (x)) $$

# %% [markdown]
# $\Huge d_0 \circ d_1$

# %%
d0d1 = sp.Matrix(composition(d0, d1))
d0d1
# Out:
# [0  0]

# %%
d0d1.shape
# Out:
# (1, 2)

# %% [markdown]
# $\Huge d_1 \circ d_2$

# %%
d1d2 = sp.Matrix(composition(d1, d2))
d1d2
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                           3
# ⎢                                                                          c ⋅
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢      k - 1                                                k - 1
# ⎢       ____                                                 ____
# ⎢       ╲                                                    ╲
# ⎢        ╲            (       k - 1      q                    ╲            (
# ⎢ 3  2    ╲  x⋅(y⋅x)     ⋅(x⋅y) ⊗       2⋅k - q - 1    2  2    ╲  (y⋅x)     ⋅(
# ⎢c ⋅d ⋅   ╱           y⋅(x⋅y)           )           + c ⋅d ⋅   ╱          y⋅(x
# ⎢        ╱                                                    ╱
# ⎢       ╱                                                    ╱
# ⎢       ‾‾‾‾                                                 ‾‾‾‾
# ⎢      q = 0                                                q = 0
# ⎣
#
#
#   k - 1                                                      k - 1
# ...

# %%
d1d2.shape
# Out:
# (2, 2)

# %% [markdown]
# $\Huge d_2 \circ d_3$

# %%
d2d3 = sp.Matrix(composition(d2, d3))
d2d3
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢0  0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢         k - 1                                       k - 1
# ⎢          ____                                        ____
# ⎢          ╲                                           ╲
# ⎢           ╲             (     q + 1                   ╲        (     q
# ⎢       2    ╲  (y⋅x)     ⊗     k      k - q - 1    2    ╲  (y⋅x) ⋅(x⋅y) ⊗
# ⎢0  0  c ⋅   ╱       (x⋅y) ⋅(y⋅x)         )      + c ⋅   ╱        (y⋅x)     )
# ⎢           ╱                                           ╱
# ⎢          ╱                                           ╱
# ⎢          ‾‾‾‾                                        ‾‾‾‾
# ⎢         q = 0                                       q = 0
# ⎣
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                           k -
#             k - 1                                                         ____
#              ____                                                         ╲
# ...

# %%
d2d3.shape
# Out:
# (2, 3)

# %% [markdown]
# $\Huge d_3 \circ d_4$

# %%
d3d4 = sp.Matrix(composition(d3, d4))
d3d4
# Out:
# ⎡0  0                                                       0
# ⎢
# ⎢      k - 1
# ⎢      _____                                   k - 1
# ⎢      ╲                                        ____
# ⎢       ╲    ⎧(y⊗       k - q - 1  for q = 0    ╲
# ⎢        ╲   ⎪ x⋅(y⋅x)         )                 ╲           (       q
# ⎢         ╲  ⎨                                    ╲  x⋅(y⋅x) ⊗     k - q - 1
# ⎢0  0     ╱  ⎪         0           otherwise +    ╱      (x⋅y)         ⋅y)
# ⎢        ╱   ⎩                                   ╱
# ⎢       ╱                                       ╱
# ⎢      ╱                                        ‾‾‾‾
# ⎢      ‾‾‾‾‾                                   q = 0
# ⎣      q = 0
#
#
#
#
#                                         k - 1                             k -
#                                          ____                              ___
#                                          ╲                                 ╲
# ...

# %%
d3d4.shape
# Out:
# (2, 4)

# %% [markdown]
# $\Huge d_4 \circ d_5$

# %%
d4d5 = sp.Matrix(composition(d4, d5))
d4d5
# Out:
# ⎡0  0                                                              0
# ⎢
# ⎢
# ⎢          k - 1                                        k - 1
# ⎢           ____                                         ____
# ⎢           ╲                                            ╲
# ⎢            ╲           (     q      k - 1               ╲                (
# ⎢             ╲  (x⋅y) ⋅(y⋅x)     ⊗     2⋅k - q - 1        ╲  x⋅(y⋅x) ⊗
# ⎢0  0  c⋅d⋅   ╱          (x⋅y)           )          + d⋅   ╱      x⋅(y⋅x)
# ⎢            ╱                                            ╱
# ⎢           ╱                                            ╱
# ⎢           ‾‾‾‾                                         ‾‾‾‾
# ⎢          q = 0                                        q = 0
# ⎢
# ⎢
# ⎣0  0                                                              0
#
#
#
#
#                                                        k - 1
#                                                         ____
# ...

# %%
d4d5.shape
# Out:
# (3, 4)
