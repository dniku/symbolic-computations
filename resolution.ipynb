# %%
import sympy as sp
sp.init_printing()

# %%
from my_resolution import d0, d1, d2, d3, d4, d5
from validate_resolution import composition

# %% [markdown]
# `composition(d0, d1)` takes two matrices $d_0$ and $d_1$ and computes the composition in the following sense:
#
# $$ \lambda x \to d_0 (d_1 (x)) $$

# %% [markdown]
# $\Huge d_0 \circ d_1$

# %%
d0d1 = sp.Matrix(composition(d0, d1))
d0d1
# Out:
# ⎡  k - 1                       k - 1
# ⎢   ____                        ____
# ⎢   ╲                           ╲
# ⎢    ╲        (     q            ╲          (     q + 1
# ⎢     ╲  (x⋅y) ⊗     k - q        ╲  (x⋅y)     ⊗     k - q - 1
# ⎢d⋅   ╱     (x⋅y)     )    + d⋅   ╱       (x⋅y)         )      + d⋅(1⊗     k +
# ⎢    ╱                           ╱                                  (x⋅y) )
# ⎢   ╱                           ╱
# ⎢   ‾‾‾‾                        ‾‾‾‾
# ⎣  q = 0                       q = 0
#
#                 k - 1                       k - 1
#                  ____                        ____
#                  ╲                           ╲
#                   ╲        (     q            ╲          (     q + 1
#                    ╲  (x⋅y) ⊗     k - q        ╲  (x⋅y)     ⊗     k - q - 1
#  d⋅ (     k   c⋅   ╱     (x⋅y)     )    + c⋅   ╱       (x⋅y)         )      +
#    (x⋅y) ⊗1)      ╱                           ╱
#                  ╱                           ╱
#                  ‾‾‾‾                        ‾‾‾‾
#                 q = 0                       q = 0
#
#                             k - 1                           k - 2
#                              ____                            ____
#                              ╲                               ╲
#                               ╲           (     q             ╲           (
#                                ╲  (y⋅x) ⊗       k - q - 1      ╲  (y⋅x)     ⊗
# c⋅(1⊗     k + c⋅ (     k  +    ╱     y⋅(x⋅y)         )    +    ╱       y⋅(x⋅y)
#    (x⋅y) )      (x⋅y) ⊗1)     ╱                               ╱
#                              ╱                               ╱
#                              ‾‾‾‾                            ‾‾‾‾
#                             q = 0                           q = 0
#
#                   k - 2                           k - 1
#                    ____                            ____
#                    ╲                               ╲
#   q + 1             ╲          (       q            ╲          (       q
#       k - q - 2      ╲  y⋅(x⋅y) ⊗     k - q - 1      ╲  y⋅(x⋅y) ⊗     k - q -
#          )      +    ╱      (x⋅y)         )     +    ╱      (x⋅y)         )
#                     ╱                               ╱
#                    ╱                               ╱
#                    ‾‾‾‾                            ‾‾‾‾
#                   q = 0                           q = 0
#
#                                      ⎤
#                                      ⎥
#                                      ⎥
#                                      ⎥
# 1                                    ⎥
#   + (1⊗       k - 1 +  (       k - 1 ⎥
#      y⋅(x⋅y)     )    y⋅(x⋅y)     ⊗1)⎥
#                                      ⎥
#                                      ⎥
#                                      ⎦

# %%
d0d1.shape
# Out:
# (1, 2)

# %% [markdown]
# $\Huge d_1 \circ d_2$

# %%
d1d2 = sp.Matrix(composition(d1, d2))
d1d2
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢      k - 1                                               k - 1
# ⎢       ____                                                ____
# ⎢       ╲                                                   ╲
# ⎢        ╲            (       k - 1      q                   ╲            (
# ⎢ 3  2    ╲  x⋅(y⋅x)     ⋅(x⋅y) ⊗       2⋅k - q - 1    3      ╲  (x⋅y)     ⊗
# ⎢c ⋅d ⋅   ╱           y⋅(x⋅y)           )           + c ⋅d⋅   ╱       y⋅(x⋅y)
# ⎢        ╱                                                   ╱
# ⎢       ╱                                                   ╱
# ⎢       ‾‾‾‾                                                ‾‾‾‾
# ⎣      q = 0                                               q = 0
#
#                                                                         k - 1
#                                                                          ____
#                                                                          ╲
#                                                                           ╲
#                                                                     3      ╲
#                                                                    c ⋅d⋅   ╱
#                                                                           ╱
#                                                                          ╱
#                                                                          ‾‾‾‾
#                                                                         q = 0
#
#                          k - 1                                             k -
#                           ____                                              __
#                           ╲                                                 ╲
#   k + q                    ╲            (     k - 1      q                   ╲
#      k - q - 1      2  2    ╲  (y⋅x)     ⋅(x⋅y) ⊗       2⋅k - q - 1    2
#         ⋅y)      + c ⋅d ⋅   ╱          y⋅(x⋅y)           )          + c ⋅d⋅
#                            ╱                                                 ╱
#                           ╱                                                 ╱
#                           ‾‾‾‾                                              ‾‾
#                          q = 0                                             q =
#
#                                                      k - 1
#                                                       ____
#                                                       ╲
#      (     k      q                                    ╲           (     k
# (x⋅y) ⋅(y⋅x) ⊗     k - q    3                    2      ╲  (x⋅y) ⋅(y⋅x) ⊗
#       (x⋅y)     )        + c ⋅d⋅   (     k    + c ⋅d⋅   ╱        (x⋅y)
#                                 (x⋅y) ⊗     k          ╱
#                                    (x⋅y) )            ╱
#                                                       ‾‾‾‾
#                                                      q = 0
#
#  1                              k - 1
# __                               ____
#                                  ╲
#          (       q                ╲            (       k + q - 1
# ╲  x⋅(x⋅y) ⊗       k - q    2      ╲  y⋅(x⋅y)         ⊗       k - q - 1
# ╱      y⋅(x⋅y)     )     + c ⋅d⋅   ╱          y⋅(x⋅y)         ⋅y)         + c⋅
#                                   ╱
#                                  ╱
# ‾‾                               ‾‾‾‾
#  0                              q = 0
#
#                    k - 1
#                     ____
#                     ╲
#   q                  ╲        (       k - 1      q
# k - q - 1      2      ╲  y⋅(x⋅y)     ⋅(y⋅x) ⊗     k - q    2
#  ⋅y)        + c ⋅d⋅   ╱           (x⋅y)     )           + c ⋅d⋅   (       k -
#                      ╱                                         y⋅(x⋅y)     ⊗
#                     ╱                                                (x⋅y) )
#                     ‾‾‾‾
#                    q = 0
#
#   k - 1                           k - 2                                   k -
#    ____                            ____                                    ___
#    ╲                               ╲                                       ╲
#     ╲         (     q               ╲           (     q + 1                 ╲
#      ╲  (x⋅y) ⊗       k - q          ╲  (x⋅y)     ⊗       k - q - 1          ╲
# d⋅   ╱     y⋅(x⋅y)     )    + c⋅d⋅   ╱       y⋅(x⋅y)         )      + c⋅d⋅   ╱
#     ╱                               ╱                                       ╱
#    ╱                               ╱                                       ╱
#    ‾‾‾‾                            ‾‾‾‾                                    ‾‾‾
#   q = 0                           q = 0                                   q =
#
#          k - 1                       k - 1
#           ____                        ____
#           ╲                           ╲
#            ╲        (     q            ╲          (     q + 1
#             ╲  (y⋅x) ⊗     k - q        ╲  (y⋅x)     ⊗     k - q - 1
# 1    + d⋅   ╱     (x⋅y)     )    + d⋅   ╱       (x⋅y)         )      + d⋅(1⊗
#    k       ╱                           ╱                                  (x⋅y
#           ╱                           ╱
#           ‾‾‾‾                        ‾‾‾‾
#          q = 0                       q = 0
#
# 1                                   k - 2
# _                                    ____
#                                      ╲
#            (       q                  ╲            (       q + 1
#   x⋅(x⋅y) ⊗       k - q - 1            ╲  x⋅(x⋅y)     ⊗       k - q - 2
#       y⋅(x⋅y)         ⋅y)     + c⋅d⋅   ╱        y⋅(x⋅y)         ⋅y)       + d⋅
#                                       ╱
#                                      ╱
# ‾                                    ‾‾‾‾
# 0                                   q = 0
#
#
#
#
#
#
#    k + d⋅ (     k
# ) )      (x⋅y) ⊗1)
#
#
#
#
# k - 1                               k - 2                                   k
#  ____                                ____                                    _
#  ╲                                   ╲                                       ╲
#   ╲            (     q                ╲            (     q + 1
#    ╲  (x⋅y) ⊗       k - q - 1          ╲  (x⋅y)     ⊗       k - q - 2
#    ╱     y⋅(x⋅y)         ⋅y)    + d⋅   ╱       y⋅(x⋅y)         ⋅y)      + d⋅
#   ╱                                   ╱
#  ╱                                   ╱                                       ╱
#  ‾‾‾‾                                ‾‾‾‾                                    ‾
# q = 0                               q = 0                                   q
#
#
#
#
#
#
#
#
#
#
#
#
# - 2                               k - 1
# ___                                ____
#                                    ╲
# ╲           (       q               ╲           (       q
#  ╲  y⋅(x⋅y) ⊗       k - q - 1        ╲  y⋅(x⋅y) ⊗       k - q - 1
#  ╱      y⋅(x⋅y)         )     + d⋅   ╱      y⋅(x⋅y)         )     + d⋅ (
# ╱                                   ╱                                 y⋅(x⋅y)
#                                    ╱
# ‾‾‾                                ‾‾‾‾
# = 0                               q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#               k - 1                                             k - 1
#                ____                                              ____
#                ╲                                                 ╲
#                 ╲            (       k - 1      q                 ╲
#           3      ╲  x⋅(y⋅x)     ⋅(x⋅y) ⊗       2⋅k - q - 1    3    ╲  (x⋅y)
#  k - 1   c ⋅d⋅   ╱           y⋅(x⋅y)           )           + c ⋅   ╱       y⋅(
#     ⊗y)         ╱                                                 ╱
#                ╱                                                 ╱
#                ‾‾‾‾                                              ‾‾‾‾
#               q = 0                                             q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#                              k - 1                                        k -
#                               ____                                         ___
#                               ╲                                            ╲
#  (     k + q                   ╲           (       k + q - 1                ╲
#   ⊗       k - q - 1      2      ╲  y⋅(x⋅y)         ⊗     2⋅k - q - 1    2    ╲
# x⋅y)         ⋅y)      + c ⋅d⋅   ╱          (y⋅x)           )         + c ⋅   ╱
#                                ╱                                            ╱
#                               ╱                                            ╱
#                               ‾‾‾‾                                         ‾‾‾
#                              q = 0                                        q =
#
#                     k - 1                                    k - 1
#                      ____                                     ____
#                      ╲                                        ╲
#                       ╲           (       k + q                ╲        (
#                   3    ╲  x⋅(y⋅x)     ⊗     k - q - 1      3    ╲  (x⋅y) ⋅(y⋅x
#                  c ⋅   ╱        (x⋅y)         ⋅y)       + c ⋅   ╱        (x⋅y)
#                       ╱                                        ╱
#                      ╱                                        ╱
#                      ‾‾‾‾                                     ‾‾‾‾
#                     q = 0                                    q = 0
#
# 1                            k - 1                                          k
# _                             ____                                           _
#                               ╲                                              ╲
#         (       q              ╲            (       k + q - 1
#   x⋅(x⋅y) ⊗       k - q    2    ╲  y⋅(x⋅y)         ⊗       k - q - 1      2
#       y⋅(x⋅y)     )     + c ⋅   ╱          y⋅(x⋅y)         ⋅y)         + c ⋅
#                                ╱
#                               ╱                                              ╱
# ‾                             ‾‾‾‾                                           ‾
# 0                            q = 0                                          q
#
#                                         k - 1
#                                          ____
#                                          ╲
# k      q                                  ╲            (     k + q
# ) ⊗     k - q    3                  2      ╲  (y⋅x)     ⊗       2⋅k - q - 2
#      )        + c ⋅   (     k    + c ⋅d⋅   ╱       x⋅(y⋅x)           )      +
#                    (x⋅y) ⊗     k          ╱
#                       (x⋅y) )            ╱
#                                          ‾‾‾‾
#                                         q = 0
#
# - 1                                              k - 1
# ___                                               ____
#                                                   ╲
# ╲        (         q                               ╲        (       k - 1
#  ╲  y⋅x⋅(x⋅y) ⊗     k - q    2                      ╲  x⋅(y⋅x)     ⋅(x⋅y) ⊗
#  ╱       (y⋅x)     )      + c ⋅(y⋅x⊗     k + c⋅d⋅   ╱           (y⋅x)     )
# ╱                                (x⋅y) )           ╱
#                                                   ╱
# ‾‾‾                                               ‾‾‾‾
# = 0                                              q = 0
#
#    k - 1                                  k - 1
#     ____                                   ____
#     ╲                                      ╲
#      ╲           (     k + q                ╲        (       k - 1      q
#  2    ╲  (y⋅x)     ⊗     k - q - 1      2    ╲  y⋅(x⋅y)     ⋅(y⋅x) ⊗     k - q
# c ⋅   ╱       (x⋅y)         ⋅y)      + c ⋅   ╱           (x⋅y)     )
#      ╱                                      ╱
#     ╱                                      ╱
#     ‾‾‾‾                                   ‾‾‾‾
#    q = 0                                  q = 0
#
#                                       k - 1                         k - 2
#                                        ____                          ____
#                                        ╲                             ╲
#  q                                      ╲         (     q             ╲
#   k - q                                  ╲  (x⋅y) ⊗       k - q        ╲  (x⋅y
#         + c⋅d⋅   (       k - 1    + c⋅   ╱     y⋅(x⋅y)     )    + c⋅   ╱
#               x⋅(y⋅x)     ⊗     k       ╱                             ╱
#                     (x⋅y) )            ╱                             ╱
#                                        ‾‾‾‾                          ‾‾‾‾
#                                       q = 0                         q = 0
#
#                               k - 1                                 k - 1
#                                ____                                  ____
#                                ╲                                     ╲
#                                 ╲            (       q                ╲
#     2                            ╲  x⋅(y⋅x) ⊗       2⋅k - q - 2        ╲  x⋅(y
#  + c ⋅   (       k - 1    + d⋅   ╱      x⋅(y⋅x)           )     + d⋅   ╱
#       y⋅(x⋅y)     ⊗     k       ╱                                     ╱
#             (x⋅y) )            ╱                                     ╱
#                                ‾‾‾‾                                  ‾‾‾‾
#                               q = 0                                 q = 0
#
#                             k - 1                                 k - 1
#                              ____                                  ____
#                              ╲                                     ╲
#     (     q + 1               ╲            (       q                ╲        (
# )     ⊗       k - q - 1        ╲  x⋅(x⋅y) ⊗       k - q - 1          ╲  y⋅(x⋅y
#  y⋅(x⋅y)         )      + c⋅   ╱      y⋅(x⋅y)         ⋅y)     + c⋅   ╱      (y
#                               ╱                                     ╱
#                              ╱                                     ╱
#                              ‾‾‾‾                                  ‾‾‾‾
#                             q = 0                                 q = 0
#
#                                 k - 1                             k - 1
#                                  ____                              ____
#                                  ╲                                 ╲
#     (       k + q - 1             ╲           (       q             ╲        (
# ⋅x)         ⊗       k - q - 1      ╲  x⋅(y⋅x) ⊗     k - q - 1        ╲  (y⋅x)
#     x⋅(y⋅x)         )         +    ╱      (x⋅y)         ⋅y)     +    ╱     (x⋅
#                                   ╱                                 ╱
#                                  ╱                                 ╱
#                                  ‾‾‾‾                              ‾‾‾‾
#                                 q = 0                             q = 0
#
#                   k - 2                                 k - 1
#                    ____                                  ____
#                    ╲                                     ╲
#        q            ╲          (       q + 1              ╲           (
# ) ⊗     k - q        ╲  y⋅(x⋅y)     ⊗     k - q - 1        ╲  y⋅x⋅(x⋅y) ⊗
# ⋅x)     )     + c⋅   ╱        (y⋅x)         )       + c⋅   ╱       y⋅(x⋅y)
#                     ╱                                     ╱
#                    ╱                                     ╱
#                    ‾‾‾‾                                  ‾‾‾‾
#                   q = 0                                 q = 0
#
#               k - 1                             k - 1
#                ____                              ____
#                ╲                                 ╲
#      q          ╲          (     q + 1            ╲           (       q
# ⊗     k - q      ╲  (y⋅x)     ⊗     k - q - 1      ╲  y⋅(y⋅x) ⊗       k - q -
# y)     )    +    ╱       (x⋅y)         )      +    ╱      x⋅(y⋅x)         )
#                 ╱                                 ╱
#                ╱                                 ╱
#                ‾‾‾‾                              ‾‾‾‾
#               q = 0                             q = 0
#
#                                                     k - 1
#                                                      ____
#                                                      ╲
#   q                                                   ╲           (     q
#   k - q - 1                                            ╲  (x⋅y) ⊗     2⋅k - q
#      )      + c⋅(y⊗     k + c⋅(y⋅x⊗       k - 1 + d⋅   ╱     (y⋅x)           )
#                  (x⋅y) )        y⋅(x⋅y)     )         ╱
#                                                      ╱
#                                                      ‾‾‾‾
#                                                     q = 0
#
#
#
#
#
# 1
#   + (1⊗     k + (y⊗       k - 1 +  (     k  +  (       k - 1
#      (x⋅y) )     x⋅(y⋅x)     )    (x⋅y) ⊗1)   x⋅(y⋅x)     ⊗y)
#
#
#
#
#         k - 1
#          ____
#          ╲
#           ╲           (       k - 1      q
# - 1        ╲  x⋅(y⋅x)     ⋅(x⋅y) ⊗       k - q - 1
#     + d⋅   ╱           y⋅(x⋅y)         )           + d⋅      (       k - 1
#           ╱                                            x⋅(y⋅x)     ⊗       k -
#          ╱                                                   y⋅(x⋅y)     )
#          ‾‾‾‾
#         q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#      k - 2                                 k - 2                             k
#       ____                                  ____
#       ╲                                     ╲
#        ╲            (     q + 1              ╲           (       q
#         ╲  (x⋅y)     ⊗       k - q - 2        ╲  y⋅(x⋅y) ⊗       k - q - 1
#    +    ╱       y⋅(x⋅y)         ⋅y)      +    ╱      y⋅(x⋅y)         )     +
#  1     ╱                                     ╱
#       ╱                                     ╱
#       ‾‾‾‾                                  ‾‾‾‾
#      q = 0                                 q = 0                             q
#
#                                                                       ⎤
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#  - 2                                                                  ⎥
# ____                                                                  ⎥
# ╲                                                                     ⎥
#  ╲           (       q + 1                                            ⎥
#   ╲  y⋅(x⋅y)     ⊗       k - q - 2                                    ⎥
#   ╱        y⋅(x⋅y)         )       + (y⊗       k - 1 +  (       k - 1 ⎥
#  ╱                                    y⋅(x⋅y)     )    y⋅(x⋅y)     ⊗y)⎥
# ╱                                                                     ⎥
# ‾‾‾‾                                                                  ⎥
#  = 0                                                                  ⎦

# %%
d1d2.shape
# Out:
# (2, 2)

# %% [markdown]
# $\Huge d_2 \circ d_3$

# %%
d2d3 = sp.Matrix(composition(d2, d3))
d2d3
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢0  0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢         k - 1                                       k - 1
# ⎢          ____                                        ____
# ⎢          ╲                                           ╲
# ⎢           ╲             (     q + 1                   ╲        (     q
# ⎢       2    ╲  (y⋅x)     ⊗     k      k - q - 1    2    ╲  (y⋅x) ⋅(x⋅y) ⊗
# ⎢0  0  c ⋅   ╱       (x⋅y) ⋅(y⋅x)         )      + c ⋅   ╱        (y⋅x)     )
# ⎢           ╱                                           ╱
# ⎢          ╱                                           ╱
# ⎢          ‾‾‾‾                                        ‾‾‾‾
# ⎣         q = 0                                       q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#             k - 1                                                           k
#              ____                                                            _
#              ╲                                                               ╲
# k             ╲           (       q      k
#  k - q    2    ╲  x⋅(y⋅x) ⋅(x⋅y) ⊗       k - q - 1    2
#        + c ⋅   ╱         y⋅(x⋅y)         )         + c ⋅   (     k    + c⋅d⋅
#               ╱                                         (x⋅y) ⊗     k
#              ╱                                             (x⋅y) )           ╱
#              ‾‾‾‾                                                            ‾
#             q = 0                                                           q
#
#
#
#
#
#
#
#
#
#
#
#
# - 1                                               k - 1
# ___                                                ____
#                                                    ╲
# ╲              (     q        k - 1                 ╲           (     k + q
#  ╲  (y⋅x) ⋅x⋅(y⋅x)     ⊗     k      k - q - 1        ╲  (x⋅y)     ⊗       k -
#  ╱            (x⋅y) ⋅(y⋅x)         )          + c⋅   ╱       y⋅(x⋅y)         )
# ╱                                                   ╱
#                                                    ╱
# ‾‾‾                                                ‾‾‾‾
# = 0                                               q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#           k - 1                                   k - 1
#            ____                                    ____
#            ╲                                       ╲
#             ╲           (       q + 1               ╲                (     q +
# q - 1        ╲  x⋅(y⋅x)     ⊗       k - q - 1        ╲  (y⋅x)     ⊗       k -
#       + c⋅   ╱        x⋅(x⋅y)         )       + c⋅   ╱       y⋅(x⋅y)     ⋅(y⋅x
#             ╱                                       ╱
#            ╱                                       ╱
#            ‾‾‾‾                                    ‾‾‾‾
#           q = 0                                   q = 0
#
#    k - 1                                             k - 1
#     ____                                              ____
#     ╲                                                 ╲
#      ╲            (     q        k - 1                 ╲           (       q
#  3    ╲  (y⋅x) ⋅x⋅(y⋅x)     ⊗       2⋅k - q - 1    3    ╲  x⋅(y⋅x) ⋅x⋅(y⋅x)
# c ⋅   ╱           x⋅(y⋅x)           )           + c ⋅   ╱            (x⋅y)
#      ╱                                                 ╱
#     ╱                                                 ╱
#     ‾‾‾‾                                              ‾‾‾‾
#    q = 0                                             q = 0
#
#                      k - 1                                    k - 1
#                       ____                                     ____
#                       ╲                                        ╲
#  1                     ╲             (       q                  ╲        (
# 1      k - q - 1        ╲  y⋅(x⋅y) ⊗     k      k - q - 1        ╲  y⋅(x⋅y)
# )         )      + c⋅   ╱      (x⋅y) ⋅(y⋅x)         )     + c⋅   ╱          (y
#                        ╱                                        ╱
#                       ╱                                        ╱
#                       ‾‾‾‾                                     ‾‾‾‾
#                      q = 0                                    q = 0
#
#                          k - 1                                          k - 1
#                           ____                                           ____
#                           ╲                                              ╲
#       k - 1                ╲                (     k + q                   ╲
#   ⊗     2⋅k - q - 1    2    ╲  (x⋅y)     ⊗       k - 1      k - q - 1      ╲
#        )            + c ⋅   ╱       x⋅(y⋅x)     ⋅(x⋅y)         )      +    ╱
#                            ╱                                              ╱
#                           ╱                                              ╱
#                           ‾‾‾‾                                           ‾‾‾‾
#                          q = 0                                          q = 0
#
#                       k - 1                           k - 1
#                        ____                            ____
#                        ╲                               ╲
#    k + q - 1            ╲         (     q               ╲        (       q
#       ⊗     k - q        ╲  (y⋅x) ⋅x⊗       k - q        ╲  x⋅(y⋅x) ⋅x⊗     k
# ⋅x)     )         + c⋅   ╱      x⋅(y⋅x)     )     + c⋅   ╱       (x⋅y)     )
#                         ╱                               ╱
#                        ╱                               ╱
#                        ‾‾‾‾                            ‾‾‾‾
#                       q = 0                           q = 0
#
#                                        k - 1
#                                         ____
#                                         ╲
#              (       q                   ╲           (     q        k - 1
# x⋅(y⋅x) ⊗       k - 1      k - q - 1      ╲  (y⋅x) ⋅x⋅(y⋅x)     ⊗       k - q
#     x⋅(y⋅x)     ⋅(x⋅y)         )     +    ╱           x⋅(y⋅x)         )
#                                          ╱
#                                         ╱
#                                         ‾‾‾‾
#                                        q = 0
#
#                                                         k - 1
#                                                          ____
#                                                          ╲
#                                                           ╲                 (
# - q                                                        ╲  (y⋅x) ⋅x⋅(y⋅x)
#     + c⋅      (     k       + c⋅   (       k - 1    + d⋅   ╱            y⋅(x⋅y
#         (x⋅y) ⊗       k - 1     y⋅(x⋅y)     ⊗     k       ╱
#            y⋅(x⋅y)     )              (x⋅y) )            ╱
#                                                          ‾‾‾‾
#                                                         q = 0
#
#       k - 1
#        ____
#        ╲
#         ╲          (       q        k - 1
# - 1      ╲  x⋅(y⋅x) ⋅x⋅(y⋅x)     ⊗     k - q - 1
#     +    ╱            (x⋅y)         )
#         ╱
#        ╱
#        ‾‾‾‾
#       q = 0
#
#                                     k - 1
#                                      ____
#                                      ╲
#     q        k - 1                    ╲           (       q        k - 1
#    ⊗       k - 1      k - q - 1        ╲  x⋅(y⋅x) ⋅x⋅(y⋅x)     ⊗       k - q -
# )     ⋅(y⋅x)         )          + d⋅   ╱            x⋅(x⋅y)         )
#                                       ╱
#                                      ╱
#                                      ‾‾‾‾
#                                     q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#      k - 1                               k - 1                       k - 1
#       ____                                ____                        ____
#       ╲                                   ╲                           ╲
#        ╲           (     q + 1             ╲        (       q          ╲
#  1      ╲  (x⋅y)     ⊗       k - q - 1      ╲  x⋅(y⋅x) ⊗     k - q      ╲  x⋅(
#    +    ╱       x⋅(x⋅y)         )      +    ╱      (x⋅y)     )     +    ╱
#        ╱                                   ╱                           ╱
#       ╱                                   ╱                           ╱
#       ‾‾‾‾                                ‾‾‾‾                        ‾‾‾‾
#      q = 0                               q = 0                       q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#                            k - 1                       k - 1
#                             ____                        ____
#                             ╲                           ╲
#     (       q + 1            ╲         (     q           ╲           (     q +
# y⋅x)     ⊗     k - q - 1      ╲  (y⋅x) ⊗       k - q      ╲  (y⋅x)     ⊗
#    (x⋅y)         )       +    ╱     x⋅(y⋅x)     )    +    ╱       x⋅(y⋅x)
#                              ╱                           ╱
#                             ╱                           ╱
#                             ‾‾‾‾                        ‾‾‾‾
#                            q = 0                       q = 0
#
#
#
#
#
#
#
#
#
#
#
#
#              k - 1                                        k - 1
#               ____                                         ____
#               ╲                                            ╲
#  1             ╲                (       q                   ╲        (     q
#  k - q - 1      ╲  y⋅(x⋅y) ⊗       k - 1      k - q - 1      ╲  (y⋅x) ⋅x⊗
#     )      +    ╱      y⋅(x⋅y)     ⋅(y⋅x)         )     +    ╱      (y⋅x)
#                ╱                                            ╱
#               ╱                                            ╱
#               ‾‾‾‾                                         ‾‾‾‾
#              q = 0                                        q = 0
#
#                                          ⎤
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#         k - 1                            ⎥
#          ____                            ⎥
#          ╲                               ⎥
#           ╲           (       q          ⎥
# k - q      ╲  x⋅(y⋅x) ⋅x⊗       k - q - 1⎥
# )     +    ╱       y⋅(x⋅y)         )     ⎥
#           ╱                              ⎥
#          ╱                               ⎥
#          ‾‾‾‾                            ⎥
#         q = 0                            ⎦

# %%
d2d3.shape
# Out:
# (2, 3)

# %% [markdown]
# $\Huge d_3 \circ d_4$

# %%
d3d4 = sp.Matrix(composition(d3, d4))
d3d4
# Out:
# ⎡0  0
# ⎢
# ⎢      k - 1                             k - 1                     k - 1
# ⎢       ____                              ____                      ____
# ⎢       ╲                                 ╲                         ╲
# ⎢        ╲           (       q             ╲        (     q          ╲
# ⎢         ╲  x⋅(y⋅x) ⊗     k - q - 1        ╲  (y⋅x) ⊗     k - q      ╲  (y⋅x)
# ⎢0  0     ╱      (x⋅y)         ⋅y)     +    ╱     (x⋅y)     )    +    ╱
# ⎢        ╱                                 ╱                         ╱
# ⎢       ╱                                 ╱                         ╱
# ⎢       ‾‾‾‾                              ‾‾‾‾                      ‾‾‾‾
# ⎣      q = 0                             q = 0                     q = 0
#
#                      0
#
#                        k - 1
#                         ____
#                         ╲
#   (     q + 1            ╲           (       q
#      ⊗     k - q - 1      ╲  y⋅(y⋅x) ⊗       k - q - 1
# (x⋅y)         )      +    ╱      x⋅(y⋅x)         )     + (1⊗     k + (y⊗
#                          ╱                                (x⋅y) )     x⋅(y⋅x)
#                         ╱
#                         ‾‾‾‾
#                        q = 0
#
#
#
#                                         k - 1                             k -
#                                          ____                              ___
#                                          ╲                                 ╲
#                                           ╲           (     q               ╲
#                                            ╲  (y⋅x) ⊗     2⋅k - q - 1        ╲
#  k - 1 +  (     k  +  (       k - 1   c⋅   ╱     (x⋅y)           )    + c⋅   ╱
#     )    (x⋅y) ⊗1)   x⋅(y⋅x)     ⊗y)      ╱                                 ╱
#                                          ╱                                 ╱
#                                          ‾‾‾‾                              ‾‾‾
#                                         q = 0                             q =
#
#
#
# 1                                                                            k
# _
#
#          (     k      q
#   (x⋅y) ⋅(y⋅x) ⊗     k - q - 1
#         (x⋅y)         )        + c⋅     (     k      + c⋅   (     k - 1    +
#                                    (x⋅y) ⊗     k - 1     (y⋅x)     ⊗     k
#                                       (x⋅y)     )             (x⋅y) )
# ‾
# 0                                                                            q
#
#        0
#
#  - 1                                      k - 1
# ____                                       ____
# ╲                                          ╲
#  ╲                (     q                   ╲          (       k - 1      q
#   ╲  (y⋅x) ⊗     k - q - 1        k - 1      ╲  y⋅(x⋅y)     ⋅(y⋅x) ⊗     k - q
#   ╱     (x⋅y)         ⋅y⋅(x⋅y)     )    +    ╱           (x⋅y)         )
#  ╱                                          ╱
# ╱                                          ╱
# ‾‾‾‾                                       ‾‾‾‾
#  = 0                                      q = 0
#
#                                                         ⎤
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#  - 1                                                    ⎥
#      +       (     k - 1       +      (       k - 1     ⎥
#        (y⋅x)     ⊗       k - 1   y⋅(x⋅y)     ⊗     k - 1⎥
#             y⋅(x⋅y)     )              (x⋅y)     )      ⎥
#                                                         ⎥
#                                                         ⎦

# %%
d3d4.shape
# Out:
# (2, 4)

# %% [markdown]
# $\Huge d_4 \circ d_5$

# %%
d4d5 = sp.Matrix(composition(d4, d5))
d4d5
# Out:
# ⎡0  0
# ⎢
# ⎢          k - 1                                        k - 1
# ⎢           ____                                         ____
# ⎢           ╲                                            ╲
# ⎢            ╲           (     q      k - 1               ╲                (
# ⎢             ╲  (x⋅y) ⋅(y⋅x)     ⊗     2⋅k - q - 1        ╲  x⋅(y⋅x) ⊗
# ⎢0  0  c⋅d⋅   ╱          (x⋅y)           )          + d⋅   ╱      x⋅(y⋅x)
# ⎢            ╱                                            ╱
# ⎢           ╱                                            ╱
# ⎢           ‾‾‾‾                                         ‾‾‾‾
# ⎢          q = 0                                        q = 0
# ⎢
# ⎢                                               k - 1                       k
# ⎢                                                ____                        _
# ⎢                                                ╲                           ╲
# ⎢                                                 ╲        (     q
# ⎢                                                  ╲  (x⋅y) ⊗     k - q
# ⎢0  0                                         d⋅   ╱     (x⋅y)     )    + d⋅
# ⎢                                                 ╱
# ⎢                                                ╱                           ╱
# ⎢                                                ‾‾‾‾                        ‾
# ⎣                                               q = 0                       q
#
#             0
#
#                          k - 1
#                           ____
#                           ╲
#      q                     ╲          (       q        k - 1
# k - 1      k - q - 1        ╲  x⋅(y⋅x) ⋅x⋅(y⋅x)     ⊗     k - q - 1
# ⋅(x⋅y)         )     + d⋅   ╱            (x⋅y)         )            + d⋅
#                            ╱                                            x⋅(y⋅x
#                           ╱
#                           ‾‾‾‾
#                          q = 0
#
# - 1
# ___
#
# ╲          (     q + 1
#  ╲  (x⋅y)     ⊗     k - q - 1
#  ╱       (x⋅y)         )      + d⋅(1⊗     k + d⋅ (     k
# ╱                                  (x⋅y) )      (x⋅y) ⊗1)
#
# ‾‾‾
# = 0
#
#
#
#                         k - 1                                        k - 1
#                          ____                                         ____
#                          ╲                                            ╲
#                           ╲           (     q      k - 1               ╲
#                       2    ╲  (x⋅y) ⋅(y⋅x)     ⊗     2⋅k - q - 1        ╲  x⋅(
# (       k - 1        c ⋅   ╱          (x⋅y)           )          + c⋅   ╱
# )     ⊗       k - 1       ╱                                            ╱
# x⋅(y⋅x)     )            ╱                                            ╱
#                          ‾‾‾‾                                         ‾‾‾‾
#                         q = 0                                        q = 0
#
#                                                                       k - 1
#                                                                        ____
#                                                                        ╲
#                                                                         ╲
#                                                                          ╲  (x
#                                                                     c⋅   ╱
#                                                                         ╱
#                                                                        ╱
#                                                                        ‾‾‾‾
#                                                                       q = 0
#
#
#
#                                       k - 2
#                                        ____
#                                        ╲
#           (       q                     ╲           (       q      k - 1
# y⋅x) ⊗       k - 1      k - q - 1        ╲  y⋅(x⋅y) ⋅(y⋅x)     ⊗     2⋅k - q -
#  x⋅(y⋅x)     ⋅(x⋅y)         )     + c⋅   ╱           (x⋅y)           )
#                                         ╱
#                                        ╱
#                                        ‾‾‾‾
#                                       q = 0
#
#                     k - 1
#                      ____
#                      ╲
#    (     q            ╲          (     q + 1
# ⋅y) ⊗     k - q        ╲  (x⋅y)     ⊗     k - q - 1
#  (x⋅y)     )    + c⋅   ╱       (x⋅y)         )      + c⋅(1⊗     k + c⋅ (     k
#                       ╱                                  (x⋅y) )      (x⋅y) ⊗1
#                      ╱
#                      ‾‾‾‾
#                     q = 0
#
#                                         0
#
#        k - 1
#         ____
#         ╲
#          ╲          (       q        k - 1
#  2        ╲  x⋅(y⋅x) ⋅x⋅(y⋅x)     ⊗     k - q - 1
#    + c⋅   ╱            (x⋅y)         )            + c⋅      (       k - 1
#          ╱                                            x⋅(y⋅x)     ⊗       k -
#         ╱                                                   x⋅(y⋅x)     )
#         ‾‾‾‾
#        q = 0
#
#     k - 1                           k - 2                               k - 2
#      ____                            ____                                ____
#      ╲                               ╲                                   ╲
#       ╲           (     q             ╲           (     q + 1             ╲
#        ╲  (y⋅x) ⊗       k - q - 1      ╲  (y⋅x)     ⊗       k - q - 2      ╲
#   +    ╱     y⋅(x⋅y)         )    +    ╱       y⋅(x⋅y)         )      +    ╱
# )     ╱                               ╱                                   ╱
#      ╱                               ╱                                   ╱
#      ‾‾‾‾                            ‾‾‾‾                                ‾‾‾‾
#     q = 0                           q = 0                               q = 0
#
#
#
#     k - 1                                      k - 1
#      ____                                       ____
#      ╲                                          ╲
#       ╲                (     q                   ╲          (     q        k -
#        ╲  (y⋅x) ⊗       k - 1      k - q - 1      ╲  (y⋅x) ⋅x⋅(y⋅x)     ⊗
#   +    ╱     x⋅(y⋅x)     ⋅(x⋅y)         )    +    ╱           (x⋅y)         )
# 1     ╱                                          ╱
#      ╱                                          ╱
#      ‾‾‾‾                                       ‾‾‾‾
#     q = 0                                      q = 0
#
#                           k - 1
#                            ____
#                            ╲
#        (       q            ╲          (       q
# y⋅(x⋅y) ⊗     k - q - 1      ╲  y⋅(x⋅y) ⊗     k - q - 1
#     (x⋅y)         )     +    ╱      (x⋅y)         )     + (1⊗       k - 1 +  (
#                             ╱                              y⋅(x⋅y)     )    y⋅
#                            ╱
#                            ‾‾‾‾
#                           q = 0
#
#                                                              ⎤
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#  1                                                           ⎥
# k - q - 1                                                    ⎥
#           +      (       k - 1      +       (     k - 1      ⎥
#             x⋅(y⋅x)     ⊗     k - 1   (y⋅x)     ⊗       k - 1⎥
#                   (x⋅y)     )              x⋅(y⋅x)     )     ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎥
#        k - 1                                                 ⎥
# (x⋅y)     ⊗1)                                                ⎥
#                                                              ⎥
#                                                              ⎥
#                                                              ⎦

# %%
d4d5.shape
# Out:
# (3, 4)
